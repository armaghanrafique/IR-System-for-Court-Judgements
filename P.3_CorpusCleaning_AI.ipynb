# %%
import os
import re
import json
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
import string
from collections import Counter
import pandas as pd
from pathlib import Path
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import warnings
warnings.filterwarnings('ignore')

# Download required NLTK data
def download_nltk_resources():
    """Download necessary NLTK resources"""
    resources = [
        'punkt',
        'stopwords',
        'wordnet',
        'averaged_perceptron_tagger'
    ]
    
    for resource in resources:
        try:
            nltk.data.find(f'tokenizers/{resource}' if resource == 'punkt' else f'corpora/{resource}')
            print(f"✅ {resource} already available")
        except LookupError:
            print(f"📥 Downloading {resource}...")
            nltk.download(resource, quiet=True)
            print(f"✅ {resource} downloaded")

class SupremeCourtCorpusPreprocessor:
    def __init__(self, txt_folder_path):
        """
        Initialize the preprocessor for Supreme Court judgements
        
        Args:
            txt_folder_path: Path to folder containing text files
        """
        self.txt_folder = txt_folder_path
        self.corpus_folder = os.path.join(os.path.dirname(self.txt_folder), "cleaned_corpus")
        
        # Setup paths
        self.setup_folders()
        
        # Initialize NLP tools
        download_nltk_resources()
        self.stop_words = set(stopwords.words('english'))
        self.lemmatizer = WordNetLemmatizer()
        self.stemmer = PorterStemmer()
        
        # Custom legal stop words for court judgements
        self.legal_stop_words = {
            'court', 'judgement', 'judgment', 'case', 'appellant', 'respondent',
            'petitioner', 'respondent', 'honourable', 'justice', 'bench',
            'supreme', 'high', 'section', 'act', 'article', 'clause',
            'hereinafter', 'aforesaid', 'whereas', 'hereinafter',
            'plaintiff', 'defendant', 'witness', 'evidence', 'exhibit',
            'dated', 'year', 'month', 'day', 'vs', 'versus', 'v',
            'no.', 'number', 'nos', 'para', 'paragraph'
        }
        
        # Combine all stop words
        self.all_stop_words = self.stop_words.union(self.legal_stop_words)
        
        # Statistics
        self.stats = {
            'total_files': 0,
            'total_words_raw': 0,
            'total_words_cleaned': 0,
            'total_sentences': 0,
            'vocabulary_size': 0,
            'most_common_words': [],
            'file_stats': [],
            'processing_time': 0
        }
        
        # Store processed data
        self.documents = []
        self.tokens_by_doc = []
        self.vocabulary = set()
        self.word_frequencies = Counter()
    
    def setup_folders(self):
        """Create necessary folders for processed data"""
        folders_to_create = [
            self.corpus_folder,
            os.path.join(self.corpus_folder, "cleaned_docs"),
            os.path.join(self.corpus_folder, "tokens"),
            os.path.join(self.corpus_folder, "statistics"),
            os.path.join(self.corpus_folder, "visualizations")
        ]
        
        for folder in folders_to_create:
            if not os.path.exists(folder):
                os.makedirs(folder)
                print(f"📁 Created: {folder}")
    
    def get_all_text_files(self):
        """Get all text files from the folder - FIXED VERSION"""
        text_files = []
        
        print(f"🔍 Scanning folder: {self.txt_folder}")
        
        try:
            # List all files in directory
            all_files = os.listdir(self.txt_folder)
            
            for filename in all_files:
                filepath = os.path.join(self.txt_folder, filename)
                
                # Check if it's a file (not directory)
                if os.path.isfile(filepath):
                    # Check if it's a text file (case insensitive)
                    if filename.lower().endswith('.txt'):
                        # Check if it's NOT an error file
                        if not filename.startswith('ERROR_'):
                            text_files.append(filepath)
            
            # Sort files alphabetically
            text_files.sort()
            
            self.stats['total_files'] = len(text_files)
            
            # Debug output
            print(f"   Found {len(text_files)} valid text files")
            if text_files:
                print(f"   First 5 files: {[os.path.basename(f) for f in text_files[:5]]}")
                if len(text_files) > 5:
                    print(f"   ... and {len(text_files) - 5} more")
            
            return text_files
            
        except Exception as e:
            print(f"❌ Error scanning folder: {e}")
            return []
    
    def remove_metadata_header(self, text):
        """Remove the conversion metadata header from text files"""
        # More robust pattern to find and remove the metadata header
        header_patterns = [
            r'=+\s*\nPDF TO TEXT CONVERSION REPORT\s*\n=+\s*\n.*?\nTEXT CONTENT:\s*\n=+\s*\n',
            r'=+\s*\nCONVERSION REPORT\s*\n=+\s*\n.*?\nTEXT:\s*\n=+\s*\n',
            r'SOURCE PDF:.*?\nTEXT CONTENT:.*?\n=+\s*\n'
        ]
        
        for pattern in header_patterns:
            match = re.search(pattern, text, re.DOTALL | re.IGNORECASE)
            if match:
                text = text[match.end():]
                break
        
        return text.strip()
    
    def clean_text_phase1(self, text):
        """Phase 1: Basic text cleaning"""
        if not text:
            return ""
        
        # Convert to lowercase
        text = text.lower()
        
        # Remove URLs
        text = re.sub(r'https?://\S+|www\.\S+', '', text)
        
        # Remove email addresses
        text = re.sub(r'\S+@\S+', '', text)
        
        # Remove special characters but keep basic punctuation and important symbols
        text = re.sub(r'[^\w\s.,!?;:()\-–—\'\"`]', ' ', text)
        
        # Replace multiple spaces/newlines/tabs with single space
        text = re.sub(r'\s+', ' ', text)
        
        # Remove standalone numbers (but keep numbers attached to words)
        text = re.sub(r'\b\d+\b', '', text)
        
        return text.strip()
    
    def clean_text_phase2(self, text):
        """Phase 2: Legal document specific cleaning"""
        # Remove case citations (e.g., [2024] SC 123, PLD 2023 SC 456)
        text = re.sub(r'\[\d{4}\]\s*\w+\s*\d+\s*\w*', '', text)
        text = re.sub(r'\b(plj|pld|mlc|scmr|scr|clr|mlj)\s*\d{4}\s*\w+\s*\d+', '', text, flags=re.IGNORECASE)
        
        # Remove section references (e.g., S. 302, Section 34, Art. 25)
        text = re.sub(r'\b(?:section|s\.?|art\.?|article|cl\.?|clause|rule|r\.?)\s*\w*\s*\d+[a-z]*', '', text, flags=re.IGNORECASE)
        
        # Remove date patterns
        text = re.sub(r'\b\d{1,2}[-/]\d{1,2}[-/]\d{2,4}\b', '', text)
        text = re.sub(r'\b(?:january|february|march|april|may|june|july|august|september|october|november|december|jan|feb|mar|apr|jun|jul|aug|sep|oct|nov|dec)[a-z]*\s+\d{1,2},?\s+\d{4}\b', '', text, flags=re.IGNORECASE)
        
        # Remove judge names patterns
        text = re.sub(r'\b(?:honourable|hon\.?|mr\.?|mrs\.?|ms\.?|justice|judge|j\.?)\s+\w+(?:\s+\w+)*\b', '', text, flags=re.IGNORECASE)
        
        # Remove court room numbers and case numbers
        text = re.sub(r'\b(?:court|cr\.?|case|no\.?|number)\s*(?:no\.?\s*)?\w*\d+\b', '', text, flags=re.IGNORECASE)
        
        # Remove common legal phrases that don't add semantic value
        legal_phrases = [
            r'in the matter of',
            r'in re:',
            r'versus\b',
            r'\bvs\.?\b',
            r'\bv\.\b',
            r'petition for',
            r'appeal against',
            r'reference made',
            r'order dated',
            r'judgment dated',
            r'passed by',
            r'heard by',
            r'presided over by',
            r'coram:',
            r'before:',
        ]
        
        for phrase in legal_phrases:
            text = re.sub(phrase, '', text, flags=re.IGNORECASE)
        
        # Remove page numbers and references
        text = re.sub(r'\bpage\s*\d+\b', '', text, flags=re.IGNORECASE)
        text = re.sub(r'\bpara\s*\d+\b', '', text, flags=re.IGNORECASE)
        text = re.sub(r'\bparagraph\s*\d+\b', '', text, flags=re.IGNORECASE)
        
        return text.strip()
    
    def clean_text_phase3(self, text):
        """Phase 3: Advanced cleaning and normalization"""
        # Remove extra whitespace (again, after phase 2)
        text = re.sub(r'\s+', ' ', text)
        
        # Remove short words (less than 2 characters) except important ones
        words = text.split()
        filtered_words = []
        
        for word in words:
            # Keep words with at least 2 characters, or important single letters
            if len(word) >= 2 or word in ['a', 'i', 'u']:
                filtered_words.append(word)
        
        text = ' '.join(filtered_words)
        
        # Normalize common legal abbreviations
        replacements = {
            'appellant': 'appellant',
            'appellants': 'appellant',
            'respondent': 'respondent',
            'respondents': 'respondent',
            'petitioner': 'petitioner',
            'petitioners': 'petitioner',
            'plaintiff': 'plaintiff',
            'plaintiffs': 'plaintiff',
            'defendant': 'defendant',
            'defendants': 'defendant',
            'judgement': 'judgment',
            'judgements': 'judgment',
            'honourable': 'honorable',
            'honble': 'honorable',
        }
        
        words = text.split()
        normalized_words = []
        for word in words:
            if word in replacements:
                normalized_words.append(replacements[word])
            else:
                normalized_words.append(word)
        
        text = ' '.join(normalized_words)
        
        return text.strip()
    
    def tokenize_text(self, text):
        """Tokenize text into words and sentences"""
        # First tokenize into sentences
        sentences = sent_tokenize(text)
        
        # Then tokenize each sentence into words
        tokens = []
        for sentence in sentences:
            # Clean sentence before tokenization
            sentence = re.sub(r'[^\w\s.,!?;:()\-]', ' ', sentence)
            words = word_tokenize(sentence)
            tokens.extend(words)
        
        return tokens, sentences
    
    def normalize_tokens(self, tokens):
        """Normalize tokens (lemmatization) with legal context"""
        normalized = []
        
        for token in tokens:
            # Skip if token is punctuation
            if token in string.punctuation:
                continue
            
            # Skip stopwords
            if token.lower() in self.all_stop_words:
                continue
            
            # Lemmatize (better for legal documents than stemming)
            lemma = self.lemmatizer.lemmatize(token.lower())
            
            # Only keep tokens with at least 2 characters
            if len(lemma) >= 2:
                normalized.append(lemma)
        
        return normalized
    
    def process_single_document(self, file_path):
        """Process a single text document"""
        file_name = os.path.basename(file_path)
        
        try:
            # Read the file with error handling
            try:
                with open(file_path, 'r', encoding='utf-8') as f:
                    text = f.read()
            except UnicodeDecodeError:
                # Try different encoding if UTF-8 fails
                with open(file_path, 'r', encoding='latin-1') as f:
                    text = f.read()
            
            # Check if file has content
            if not text or len(text.strip()) < 10:
                print(f"   ⚠️ File is empty or too short: {file_name}")
                return None
            
            # Remove metadata header
            text = self.remove_metadata_header(text)
            
            # Phase 1: Basic cleaning
            text_phase1 = self.clean_text_phase1(text)
            
            # Phase 2: Legal-specific cleaning
            text_phase2 = self.clean_text_phase2(text_phase1)
            
            # Phase 3: Advanced cleaning
            text_phase3 = self.clean_text_phase3(text_phase2)
            
            # Tokenization
            raw_tokens, sentences = self.tokenize_text(text_phase3)
            
            # Check if we have tokens
            if not raw_tokens:
                print(f"   ⚠️ No tokens extracted: {file_name}")
                return None
            
            # Normalize tokens
            clean_tokens = self.normalize_tokens(raw_tokens)
            
            # Calculate statistics
            file_stats = {
                'file_name': file_name,
                'raw_text_length': len(text),
                'cleaned_text_length': len(text_phase3),
                'sentence_count': len(sentences),
                'raw_token_count': len(raw_tokens),
                'clean_token_count': len(clean_tokens),
                'unique_tokens': len(set(clean_tokens)),
                'avg_sentence_length': len(raw_tokens) / len(sentences) if sentences else 0
            }
            
            return {
                'file_name': file_name,
                'original_text': text[:500] + "..." if len(text) > 500 else text,  # Store only preview
                'cleaned_text': text_phase3,
                'raw_tokens': raw_tokens,
                'clean_tokens': clean_tokens,
                'sentences': sentences,
                'stats': file_stats
            }
            
        except Exception as e:
            print(f"❌ Error processing {file_name}: {str(e)[:80]}")
            return None
    
    def create_corpus(self):
        """Create a cleaned corpus from all text files"""
        print("=" * 80)
        print("⚖️  SUPREME COURT JUDGEMENTS CORPUS PREPROCESSING")
        print("=" * 80)
        
        start_time = datetime.now()
        
        # Get all text files
        text_files = self.get_all_text_files()
        
        if not text_files:
            print(f"\n❌ No text files found in: {self.txt_folder}")
            
            # Show what's in the folder
            self.debug_folder_contents()
            return False
        
        print(f"\n📁 Text Folder: {self.txt_folder}")
        print(f"📁 Corpus Folder: {self.corpus_folder}")
        print(f"📚 Found {len(text_files)} text file(s)")
        print("=" * 80)
        
        # Process each file
        successful_files = 0
        failed_files = []
        
        for idx, file_path in enumerate(text_files, 1):
            print(f"\n[{idx}/{len(text_files)}] Processing: {os.path.basename(file_path)}")
            
            result = self.process_single_document(file_path)
            
            if result:
                # Store processed data
                self.documents.append(result)
                self.tokens_by_doc.append(result['clean_tokens'])
                self.vocabulary.update(result['clean_tokens'])
                self.word_frequencies.update(result['clean_tokens'])
                self.stats['file_stats'].append(result['stats'])
                
                # Update statistics
                self.stats['total_words_raw'] += result['stats']['raw_token_count']
                self.stats['total_words_cleaned'] += result['stats']['clean_token_count']
                self.stats['total_sentences'] += result['stats']['sentence_count']
                
                # Save cleaned document
                cleaned_doc_path = os.path.join(
                    self.corpus_folder, 
                    "cleaned_docs", 
                    result['file_name']
                )
                with open(cleaned_doc_path, 'w', encoding='utf-8') as f:
                    f.write(result['cleaned_text'])
                
                # Save tokens
                tokens_path = os.path.join(
                    self.corpus_folder,
                    "tokens",
                    f"{os.path.splitext(result['file_name'])[0]}_tokens.txt"
                )
                with open(tokens_path, 'w', encoding='utf-8') as f:
                    f.write('\n'.join(result['clean_tokens']))
                
                print(f"   ✅ Cleaned: {result['stats']['clean_token_count']:,} tokens")
                successful_files += 1
            else:
                failed_files.append(os.path.basename(file_path))
                print(f"   ❌ Failed to process")
        
        # Check if we processed any files
        if successful_files == 0:
            print(f"\n❌ No files were successfully processed!")
            return False
        
        # Finalize statistics
        self.stats['vocabulary_size'] = len(self.vocabulary)
        self.stats['most_common_words'] = self.word_frequencies.most_common(50)
        self.stats['processing_time'] = (datetime.now() - start_time).total_seconds()
        
        # Save processed data
        self.save_processed_data()
        self.generate_statistics_report()
        
        # Create visualizations (optional - can be commented out if causing issues)
        try:
            self.create_visualizations()
        except Exception as e:
            print(f"⚠️ Could not create visualizations: {e}")
        
        # Print summary
        self.print_summary()
        
        # Show failed files if any
        if failed_files:
            print(f"\n⚠️  Failed to process {len(failed_files)} files:")
            for i, failed in enumerate(failed_files[:10], 1):
                print(f"   {i}. {failed}")
            if len(failed_files) > 10:
                print(f"   ... and {len(failed_files) - 10} more")
        
        return True
    
    def debug_folder_contents(self):
        """Debug: Show what's in the folder"""
        print(f"\n📂 Contents of {self.txt_folder}:")
        try:
            items = os.listdir(self.txt_folder)
            print(f"   Total items: {len(items)}")
            
            # Count by type
            files = []
            dirs = []
            
            for item in items[:20]:  # Show first 20
                item_path = os.path.join(self.txt_folder, item)
                if os.path.isfile(item_path):
                    files.append(item)
                elif os.path.isdir(item_path):
                    dirs.append(item)
            
            print(f"   Files: {len(files)}")
            print(f"   Directories: {len(dirs)}")
            
            # Show text files
            txt_files = [f for f in files if f.lower().endswith('.txt')]
            print(f"\n   Text files found: {len(txt_files)}")
            for txt in txt_files[:10]:
                print(f"     • {txt}")
            
        except Exception as e:
            print(f"   Error reading folder: {e}")
    
    def save_processed_data(self):
        """Save all processed data to files"""
        print("\n💾 Saving processed data...")
        
        # Save vocabulary
        vocab_path = os.path.join(self.corpus_folder, "vocabulary.txt")
        with open(vocab_path, 'w', encoding='utf-8') as f:
            sorted_vocab = sorted(self.vocabulary)
            f.write('\n'.join(sorted_vocab))
        print(f"   ✅ Vocabulary: {len(self.vocabulary):,} words saved")
        
        # Save word frequencies
        freq_path = os.path.join(self.corpus_folder, "word_frequencies.json")
        with open(freq_path, 'w', encoding='utf-8') as f:
            json.dump(dict(self.word_frequencies.most_common()), f, indent=2)
        
        # Save document-token mapping
        doc_tokens_path = os.path.join(self.corpus_folder, "document_tokens.json")
        doc_tokens_data = {}
        for doc in self.documents:
            doc_tokens_data[doc['file_name']] = {
                'tokens': doc['clean_tokens'][:500],  # First 500 tokens only
                'token_count': len(doc['clean_tokens'])
            }
        with open(doc_tokens_path, 'w', encoding='utf-8') as f:
            json.dump(doc_tokens_data, f, indent=2)
        
        # Save complete corpus (all cleaned text in one file)
        corpus_path = os.path.join(self.corpus_folder, "complete_corpus.txt")
        with open(corpus_path, 'w', encoding='utf-8') as f:
            for doc in self.documents:
                f.write(f"\n\n{'='*80}\n")
                f.write(f"DOCUMENT: {doc['file_name']}\n")
                f.write(f"TOKENS: {len(doc['clean_tokens']):,}\n")
                f.write(f"{'='*80}\n\n")
                f.write(doc['cleaned_text'])
        
        # Save statistics
        stats_path = os.path.join(self.corpus_folder, "corpus_statistics.json")
        with open(stats_path, 'w', encoding='utf-8') as f:
            json.dump(self.stats, f, indent=2)
        
        print("   ✅ All processed data saved")
    
    def generate_statistics_report(self):
        """Generate comprehensive statistics report"""
        print("\n📊 Generating statistics report...")
        
        # Create statistics directory
        stats_dir = os.path.join(self.corpus_folder, "statistics")
        
        # 1. Basic statistics
        basic_stats = {
            "corpus_statistics": {
                "total_documents": len(self.documents),
                "total_sentences": self.stats['total_sentences'],
                "total_words_raw": self.stats['total_words_raw'],
                "total_words_cleaned": self.stats['total_words_cleaned'],
                "vocabulary_size": self.stats['vocabulary_size'],
                "average_words_per_document": self.stats['total_words_cleaned'] / len(self.documents) if self.documents else 0,
                "average_sentences_per_document": self.stats['total_sentences'] / len(self.documents) if self.documents else 0,
                "processing_time_seconds": self.stats['processing_time']
            }
        }
        
        with open(os.path.join(stats_dir, "basic_statistics.json"), 'w', encoding='utf-8') as f:
            json.dump(basic_stats, f, indent=2)
        
        # 2. Document-level statistics
        doc_stats_df = pd.DataFrame(self.stats['file_stats'])
        doc_stats_df.to_csv(os.path.join(stats_dir, "document_statistics.csv"), index=False)
        
        # 3. Word frequency statistics
        word_stats = []
        for word, freq in self.word_frequencies.most_common(1000):
            word_stats.append({
                'word': word,
                'frequency': freq,
                'percentage': (freq / self.stats['total_words_cleaned']) * 100
            })
        
        word_stats_df = pd.DataFrame(word_stats)
        word_stats_df.to_csv(os.path.join(stats_dir, "word_frequencies.csv"), index=False)
        
        print("   ✅ Statistics reports generated")
    
    def create_visualizations(self):
        """Create visualizations of the corpus"""
        print("\n🎨 Creating visualizations...")
        
        viz_dir = os.path.join(self.corpus_folder, "visualizations")
        
        try:
            # Combine all tokens for word cloud
            all_text = ' '.join([' '.join(doc['clean_tokens']) for doc in self.documents])
            
            if all_text.strip():
                # 1. Word Cloud
                wordcloud = WordCloud(
                    width=1200,
                    height=800,
                    background_color='white',
                    max_words=200,
                    contour_width=3,
                    contour_color='steelblue'
                ).generate(all_text)
                
                plt.figure(figsize=(15, 10))
                plt.imshow(wordcloud, interpolation='bilinear')
                plt.axis('off')
                plt.title('Supreme Court Judgements Word Cloud', fontsize=20, pad=20)
                plt.savefig(os.path.join(viz_dir, 'wordcloud.png'), dpi=300, bbox_inches='tight')
                plt.close()
                
                # 2. Top 20 words bar chart
                top_words = self.word_frequencies.most_common(20)
                if top_words:
                    words, freqs = zip(*top_words)
                    
                    plt.figure(figsize=(15, 8))
                    plt.barh(range(len(words)), freqs, color='steelblue')
                    plt.yticks(range(len(words)), words)
                    plt.xlabel('Frequency')
                    plt.title('Top 20 Most Frequent Words')
                    plt.gca().invert_yaxis()
                    plt.tight_layout()
                    plt.savefig(os.path.join(viz_dir, 'top_words.png'), dpi=300)
                    plt.close()
                
                print("   ✅ Visualizations created")
            else:
                print("   ⚠️ No text for visualizations")
                
        except Exception as e:
            print(f"   ⚠️ Could not create visualizations: {e}")
    
    def print_summary(self):
        """Print preprocessing summary"""
        print("\n" + "=" * 80)
        print("📊 PREPROCESSING SUMMARY")
        print("=" * 80)
        
        print(f"\n📁 CORPUS LOCATION:")
        print(f"   {os.path.abspath(self.corpus_folder)}")
        
        print(f"\n📊 BASIC STATISTICS:")
        print(f"   Documents Processed: {len(self.documents):,}")
        print(f"   Total Sentences: {self.stats['total_sentences']:,}")
        print(f"   Total Words (Raw): {self.stats['total_words_raw']:,}")
        print(f"   Total Words (Cleaned): {self.stats['total_words_cleaned']:,}")
        print(f"   Vocabulary Size: {self.stats['vocabulary_size']:,}")
        print(f"   Processing Time: {self.stats['processing_time']:.2f} seconds")
        
        print(f"\n📈 AVERAGE PER DOCUMENT:")
        avg_words = self.stats['total_words_cleaned'] / len(self.documents) if self.documents else 0
        avg_sents = self.stats['total_sentences'] / len(self.documents) if self.documents else 0
        print(f"   Words: {avg_words:,.0f}")
        print(f"   Sentences: {avg_sents:,.0f}")
        
        print(f"\n🔤 TOP 10 MOST FREQUENT WORDS:")
        for i, (word, freq) in enumerate(self.stats['most_common_words'][:10], 1):
            percentage = (freq / self.stats['total_words_cleaned']) * 100
            print(f"   {i:2d}. {word:20s} {freq:8,d} ({percentage:.2f}%)")
        
        print(f"\n📂 CREATED FOLDERS:")
        folders = [
            "cleaned_docs/ - Individual cleaned documents",
            "tokens/ - Tokenized versions",
            "statistics/ - Statistical reports",
            "visualizations/ - Charts and graphs"
        ]
        for folder in folders:
            print(f"   • {folder}")
        
        print(f"\n📄 CREATED FILES:")
        files = [
            "complete_corpus.txt - All documents combined",
            "vocabulary.txt - Complete vocabulary list",
            "word_frequencies.json - Word frequency data",
            "document_tokens.json - Document-token mapping",
            "corpus_statistics.json - Complete statistics"
        ]
        for file in files:
            print(f"   • {file}")
    
    def get_corpus_info(self):
        """Return corpus information for further processing"""
        return {
            'documents': self.documents,
            'vocabulary': list(self.vocabulary),
            'word_frequencies': self.word_frequencies,
            'tokens_by_doc': self.tokens_by_doc,
            'stats': self.stats
        }

def main():
    """Main function"""
    print("=" * 80)
    print("⚖️  SUPREME COURT JUDGEMENTS - CORPUS PREPROCESSING")
    print("=" * 80)
    
    # Set text folder path
    txt_folder = r"C:\Users\Armaghan Rafique\Desktop\AI Project\supreme_court_judgements_txt"
    
    # Verify the folder exists
    if not os.path.exists(txt_folder):
        print(f"\n❌ Error: Folder not found: {txt_folder}")
        
        # Suggest alternatives
        current_dir = os.getcwd()
        print(f"\nCurrent directory: {current_dir}")
        print("Looking for text files in:")
        
        # Check common locations
        possible_locations = [
            os.path.join(current_dir, "supreme_court_judgements_txt"),
            os.path.join(os.path.dirname(current_dir), "supreme_court_judgements_txt"),
            os.path.join(os.path.expanduser('~'), "Desktop", "AI Project", "supreme_court_judgements_txt")
        ]
        
        found = False
        for loc in possible_locations:
            if os.path.exists(loc):
                print(f"✅ Found: {loc}")
                txt_folder = loc
                found = True
                break
        
        if not found:
            alt_path = input("\nEnter correct folder path: ").strip()
            if alt_path:
                txt_folder = alt_path
            else:
                return
    
    # First verify the folder
    print(f"\n🔍 Verifying folder: {txt_folder}")
    
    if not os.path.exists(txt_folder):
        print(f"❌ Folder does not exist!")
        return
    
    # Count files
    try:
        files = [f for f in os.listdir(txt_folder) if os.path.isfile(os.path.join(txt_folder, f))]
        txt_files = [f for f in files if f.lower().endswith('.txt')]
        
        print(f"📂 Total files in folder: {len(files)}")
        print(f"📝 Text files found: {len(txt_files)}")
        
        if len(txt_files) == 0:
            print(f"\n❌ No text files found!")
            print(f"\nFirst 10 files in folder:")
            for f in files[:10]:
                print(f"  • {f}")
            return
        
    except Exception as e:
        print(f"❌ Error reading folder: {e}")
        return
    
    # Create and run preprocessor
    print(f"\n🚀 Starting corpus preprocessing...")
    
    preprocessor = SupremeCourtCorpusPreprocessor(txt_folder)
    
    # Start preprocessing
    success = preprocessor.create_corpus()
    
    if success:
        print("\n" + "=" * 80)
        print("🎉 CORPUS PREPROCESSING COMPLETED!")
        print("=" * 80)
        
        # Get corpus info for further processing
        corpus_info = preprocessor.get_corpus_info()
        
        print(f"\n📂 Your corpus is ready at:")
        print(f"   {os.path.abspath(preprocessor.corpus_folder)}")
        
        print(f"\n📝 Next steps you can take:")
        print(f"   1. Train word embeddings (Word2Vec, GloVe)")
        print(f"   2. Create TF-IDF matrix")
        print(f"   3. Train topic models (LDA, NMF)")
        print(f"   4. Build a search engine")
        print(f"   5. Train a text classifier")
        
        return corpus_info
    else:
        print("\n❌ Preprocessing failed")
        return None

# Simple test function
def test_preprocessing():
    """Test preprocessing on a small sample"""
    txt_folder = r"C:\Users\Armaghan Rafique\Desktop\AI Project\supreme_court_judgements_txt"
    
    if not os.path.exists(txt_folder):
        print(f"❌ Folder not found: {txt_folder}")
        return
    
    # Get first 5 text files
    files = [f for f in os.listdir(txt_folder) 
             if os.path.isfile(os.path.join(txt_folder, f)) 
             and f.lower().endswith('.txt')]
    
    if not files:
        print("❌ No text files found")
        return
    
    files = files[:5]  # Take first 5
    
    print(f"Testing preprocessing on {len(files)} files:")
    for f in files:
        print(f"  • {f}")
    
    # Create preprocessor
    preprocessor = SupremeCourtCorpusPreprocessor(txt_folder)
    
    # Test single file
    test_file = os.path.join(txt_folder, files[0])
    print(f"\n📄 Testing file: {files[0]}")
    
    result = preprocessor.process_single_document(test_file)
    
    if result:
        print(f"✅ Successfully processed")
        print(f"   Original length: {result['stats']['raw_text_length']:,} chars")
        print(f"   Cleaned tokens: {len(result['clean_tokens']):,}")
        print(f"   Sample tokens: {', '.join(result['clean_tokens'][:20])}...")
    else:
        print(f"❌ Failed to process")

if __name__ == "__main__":
    # You can run either:
    # 1. Full preprocessing
    corpus_result = main()
    
    # 2. Or test on a small sample first
    # test_preprocessing()
# Out:
# ================================================================================
# ⚖️  SUPREME COURT JUDGEMENTS - CORPUS PREPROCESSING
# ================================================================================
#
# 🔍 Verifying folder: C:\Users\Armaghan Rafique\Desktop\AI Project\supreme_court_judgements_txt
# 📂 Total files in folder: 1475
# 📝 Text files found: 1474
#
# 🚀 Starting corpus preprocessing...
# 📁 Created: C:\Users\Armaghan Rafique\Desktop\AI Project\cleaned_corpus
# 📁 Created: C:\Users\Armaghan Rafique\Desktop\AI Project\cleaned_corpus\cleaned_docs
# 📁 Created: C:\Users\Armaghan Rafique\Desktop\AI Project\cleaned_corpus\tokens
# 📁 Created: C:\Users\Armaghan Rafique\Desktop\AI Project\cleaned_corpus\statistics
# 📁 Created: C:\Users\Armaghan Rafique\Desktop\AI Project\cleaned_corpus\visualizations
# ✅ punkt already available
# ✅ stopwords already available
# 📥 Downloading wordnet...
# ✅ wordnet downloaded
# 📥 Downloading averaged_perceptron_tagger...
# ✅ averaged_perceptron_tagger downloaded
# ================================================================================
# ⚖️  SUPREME COURT JUDGEMENTS CORPUS PREPROCESSING
# ================================================================================
# 🔍 Scanning folder: C:\Users\Armaghan Rafique\Desktop\AI Project\supreme_court_judgements_txt
#    Found 1460 valid text files
#    First 5 files: ['1_Tajuddin_2_Gul_Alam_sons_of_Mir_Alam_VERSUS_M__5_._20tajuddin_20etc_20vs_20Mst_20Zainab.txt', '2025LHC7211.txt', '2025LHC7227.txt', '2025LHC7236.txt', '2025LHC7261.txt']
#    ... and 1455 more
#
# 📁 Text Folder: C:\Users\Armaghan Rafique\Desktop\AI Project\supreme_court_judgements_txt
# 📁 Corpus Folder: C:\Users\Armaghan Rafique\Desktop\AI Project\cleaned_corpus
# 📚 Found 1460 text file(s)
# ================================================================================
#
# [1/1460] Processing: 1_Tajuddin_2_Gul_Alam_sons_of_Mir_Alam_VERSUS_M__5_._20tajuddin_20etc_20vs_20Mst_20Zainab.txt
#    ✅ Cleaned: 760 tokens
#
# [2/1460] Processing: 2025LHC7211.txt
#    ✅ Cleaned: 3,422 tokens
#
# [3/1460] Processing: 2025LHC7227.txt
#    ✅ Cleaned: 1,607 tokens
#
# [4/1460] Processing: 2025LHC7236.txt
#    ✅ Cleaned: 5,117 tokens
#
# [5/1460] Processing: 2025LHC7261.txt
#    ✅ Cleaned: 871 tokens
#
# [6/1460] Processing: 2025LHC7266.txt
#    ✅ Cleaned: 2,025 tokens
#
# [7/1460] Processing: 2025LHC7277.txt
#    ✅ Cleaned: 1,051 tokens
#
# [8/1460] Processing: 2025LHC7298.txt
#    ✅ Cleaned: 912 tokens
#
# [9/1460] Processing: 2025LHC7304.txt
#    ✅ Cleaned: 930 tokens
#
# [10/1460] Processing: 2025LHC7310.txt
#    ✅ Cleaned: 854 tokens
#
# [11/1460] Processing: 2025LHC7319.txt
#    ✅ Cleaned: 1,738 tokens
#
# [12/1460] Processing: 2025LHC7330.txt
#    ✅ Cleaned: 842 tokens
#
# [13/1460] Processing: 2025LHC7336.txt
#    ✅ Cleaned: 1,139 tokens
#
# [14/1460] Processing: 2025LHC7342.txt
#    ✅ Cleaned: 2,373 tokens
#
# [15/1460] Processing: 2025LHC7354.txt
#    ✅ Cleaned: 1,595 tokens
#
# [16/1460] Processing: 2025LHC7363.txt
#    ✅ Cleaned: 1,050 tokens
#
# [17/1460] Processing: 2025LHC7370.txt
#    ✅ Cleaned: 3,040 tokens
#
# [18/1460] Processing: 2025LHC7389.txt
#    ✅ Cleaned: 6,103 tokens
#
# [19/1460] Processing: 2025LHC7429.txt
#    ✅ Cleaned: 842 tokens
#
# [20/1460] Processing: 2025LHC7437.txt
#    ✅ Cleaned: 6,891 tokens
#
# [21/1460] Processing: 2025LHC7483.txt
#    ✅ Cleaned: 1,024 tokens
#
# [22/1460] Processing: 2025LHC7491.txt
#    ✅ Cleaned: 2,677 tokens
#
# [23/1460] Processing: 2025LHC7508.txt
#    ✅ Cleaned: 5,160 tokens
#
# [24/1460] Processing: 2025LHC7540.txt
#    ✅ Cleaned: 5,030 tokens
#
# [25/1460] Processing: 2025LHC7573.txt
#    ✅ Cleaned: 1,678 tokens
#
# [26/1460] Processing: 2025LHC7583.txt
#    ✅ Cleaned: 4,272 tokens
#
# [27/1460] Processing: 2025LHC7611.txt
#    ✅ Cleaned: 798 tokens
#
# [28/1460] Processing: 2025LHC7618.txt
#    ✅ Cleaned: 767 tokens
#
# [29/1460] Processing: 2025LHC7624.txt
#    ✅ Cleaned: 959 tokens
#
# [30/1460] Processing: 2025LHC7631.txt
#    ✅ Cleaned: 10,326 tokens
#
# [31/1460] Processing: 2025LHC7690.txt
#    ✅ Cleaned: 2,208 tokens
#
# [32/1460] Processing: 2025LHC7704.txt
#    ✅ Cleaned: 855 tokens
#
# [33/1460] Processing: 2025LHC7713.txt
#    ✅ Cleaned: 727 tokens
#
# [34/1460] Processing: 2025LHC7720.txt
#    ✅ Cleaned: 1,986 tokens
#
# [35/1460] Processing: 2025LHC7732.txt
#    ✅ Cleaned: 1,143 tokens
#
# [36/1460] Processing: 2025LHC7739.txt
#    ✅ Cleaned: 1,655 tokens
#
# [37/1460] Processing: 2025LHC7754.txt
#    ✅ Cleaned: 1,052 tokens
#
# [38/1460] Processing: 2025LHC7761.txt
#    ✅ Cleaned: 1,788 tokens
#
# [39/1460] Processing: 2025LHC7772.txt
#    ✅ Cleaned: 624 tokens
#
# [40/1460] Processing: 2025LHC7777.txt
#    ✅ Cleaned: 587 tokens
#
# [41/1460] Processing: 2025LHC7782.txt
#    ✅ Cleaned: 673 tokens
#
# [42/1460] Processing: 2025LHC7788.txt
#    ✅ Cleaned: 611 tokens
#
# [43/1460] Processing: 2025LHC7793.txt
#    ✅ Cleaned: 654 tokens
#
# [44/1460] Processing: 2025LHC7797.txt
#    ✅ Cleaned: 1,923 tokens
#
# [45/1460] Processing: 2025LHC7806.txt
#    ✅ Cleaned: 1,222 tokens
#
# [46/1460] Processing: 2025LHC7814.txt
#    ✅ Cleaned: 1,190 tokens
#
# [47/1460] Processing: 2025LHC7822.txt
#    ✅ Cleaned: 1,253 tokens
#
# [48/1460] Processing: 2025LHC7830.txt
#    ✅ Cleaned: 406 tokens
#
# [49/1460] Processing: 2025LHC7834.txt
#    ✅ Cleaned: 1,019 tokens
#
# [50/1460] Processing: 2025LHC7841.txt
#    ✅ Cleaned: 1,254 tokens
#
# [51/1460] Processing: 5. final judgment of nafeesa kiran.txt
#    ✅ Cleaned: 731 tokens
#
# [52/1460] Processing: ADMINISTRATIVE_APPEALREPRESENTATION_NO012013_administrative_20appeal.txt
#    ✅ Cleaned: 1,029 tokens
#
# [53/1460] Processing: Abbas_and_others_versus_Raza_others_Abbas_20__20others_20versus_20Raza_20__20others_20SKD_20Branch.txt
#    ✅ Cleaned: 500 tokens
#
#    ✅ Cleaned: 392 tokens
#
# [89/1460] Processing: Ali_Khan_Versus_Provincial_Government_Ali_20Khan_20versus_20Provincial_20Govt.txt
#    ✅ Cleaned: 979 tokens
#
# [90/1460] Processing: All_Employees_of_NATCO_Versus_Zafar_Iqbal_MD_NATCO_all_employee_of_NATCO_vs_Zafar_Iqbal.txt
#    ✅ Cleaned: 31 tokens
#
# [91/1460] Processing: All_Gilgit-Baltistan_workers_federation_all_gilgit_baltistan_workers_federation.txt
#    ✅ Cleaned: 4,452 tokens
#
# [92/1460] Processing: All_Residents_of_Fultux_Versus_Muhammad_Ali_judgement_20of_20all_20residents_20of_20fultux.txt
#    ✅ Cleaned: 282 tokens
#
# [93/1460] Processing: All_Residents_of_Mausa_Shella_Versus_All_Residents_All_20Residents_20of_20Mausa_20Shella.txt
#    ✅ Cleaned: 398 tokens
#
# [94/1460] Processing: Allied_Bank_versus_KCBL_Allied_Bank_versus_KCBL.txt
#    ✅ Cleaned: 28 tokens
#
# [95/1460] Processing: Allotment_of_Land_to_the_Refugees_of_Village_Mir_M_smc_20no._2025-2011.txt
#    ✅ Cleaned: 1,117 tokens
#
# [96/1460] Processing: Altaf_Hussain_Justice_retired_and_others_Versus_Sy_Justice_Altaf_Hussain_vs_mutahir_ali_shah.txt
#    ✅ Cleaned: 319 tokens
#
# [97/1460] Processing: Amaiz_Khan_another_Versus_Mazhar_Hussain_anoth_Amaiz_20Khan_20Versus_20Mazhar_20Hussain.txt
#    ✅ Cleaned: 85 tokens
#
# [98/1460] Processing: Amir_Khan_versus_Habib-ur-Rehman_others_Amir_Khan_versus_Habib-ur-Rehman___others.txt
#    ✅ Cleaned: 63 tokens
#
# [99/1460] Processing: Amir_Shah_Versus_Mst_Khosh_Joor_Amir_20Shah.txt
#    ✅ Cleaned: 133 tokens
#
# [100/1460] Processing: Amir_Shah_Versus_Mst_Khosh_Joor_WO_Gairat_Shah_a_Amir_Shah_vs_Mst._Khosh_Joor.txt
#    ✅ Cleaned: 204 tokens
#
# [101/1460] Processing: Anwar_Khan_others_Versus_Mst_Saifora_others_Anwar_Khan_Vs_Mst._Saifora.txt
#    ✅ Cleaned: 62 tokens
#
# [102/1460] Processing: Appeal_No472015_in_CPLA_NO252014_Syed_20Faiz_20ALi_20Shah-.txt
#    ✅ Cleaned: 449 tokens
#
# [103/1460] Processing: Application_of_Malik_Kifayat-ur-Rehman_regarding_e_Application_20of_20malik_20Kifayat_20Rehman.txt
#    ✅ Cleaned: 878 tokens
#
# [104/1460] Processing: Arif-ud-Din_Versus_The_State_judgment_20of_20Arif-ud-Din.txt
#    ✅ Cleaned: 667 tokens
#
# [105/1460] Processing: Arshad_wali_and_other_Versus_The_State_Cr.Misc._No._23-2009.txt
#    ✅ Cleaned: 476 tokens
#
# [106/1460] Processing: Asad_Ullah_Khan_Advocate_and_04_others_Versus_The_Asad_20Ullah_20Khan_20and_20others_20versus_20Registrar_20sac_20.txt
#    ✅ Cleaned: 269 tokens
#
# [107/1460] Processing: Ashfaq_So_Ghulam_Muhammad_Versus_The_State_cr.Misc._No._26-2009.txt
#    ✅ Cleaned: 636 tokens
#
# [108/1460] Processing: Ashfaq_Versus_The_State_ashfaq_vs_state.txt
#    ✅ Cleaned: 625 tokens
#
# [109/1460] Processing: Ashoor_khan_Others_Versus_Qasim_Shah_Others_Ashoor_khan_vs_the_state.txt
#    ✅ Cleaned: 280 tokens
#
# [110/1460] Processing: Ashrat_Versus_The_State_Ashrat.txt
#    ✅ Cleaned: 413 tokens
#
# [111/1460] Processing: Asif_Hussain_Vs_The_State_Asif_20Hussain_20VR_20The_20State.txt
#    ✅ Cleaned: 112 tokens
#
# [112/1460] Processing: Asif_Hussain_versus_The_State_Asif_Hussain_VR_The_State.txt
#    ✅ Cleaned: 112 tokens
#
# [113/1460] Processing: Asif_Khan_so_Mirbaz_Khan_Versus_The_State_cr.misc.no.09-2011.txt
#    ✅ Cleaned: 158 tokens
#
# [114/1460] Processing: Assistant_Collector_Custom_Sust_Gojal_Versus_Syed_assistant_collector_custom_vs_syed_m._riaz.txt
#    ✅ Cleaned: 793 tokens
#
# [115/1460] Processing: Ateeq_Hussain_Versus_The_State_The_State_Versus_S_Ateeq_hussain_vs_the_state.txt
#    ✅ Cleaned: 2,008 tokens
#
# [116/1460] Processing: Atta-ur-Rehaman_versus_The_State_Atta-ur-Rehaman_versus_the_State.txt
#    ✅ Cleaned: 170 tokens
#
# [117/1460] Processing: Ayesha_Subhani_daughter_of_Syed_Zahid_Hussain_Vers_Ayesha_20subhani_20vs_20Syed_20Juniad_20Arshad.txt
#    ✅ Cleaned: 431 tokens
#
# [118/1460] Processing: Azima_Shaheen_Versus_Provincial_Government_other_Azima_20Shaheen_20versus_20Pro._20Govt.txt
#    ✅ Cleaned: 354 tokens
#
# [119/1460] Processing: Aziz-ur-Rehman_Versus_Muhammad_Ishaque_Chief_Engin_Aziz-ur-Rehman_20versus_20Mohd_20Ishaq_20Chief_20Engineer.txt
#    ✅ Cleaned: 241 tokens
#
# [120/1460] Processing: Babar_Khan_DSP_Versus_Government_of_GB_others_Babar_Khan_DSP_versus_Prov._Govt._Review.txt
#    ✅ Cleaned: 85 tokens
#
# [121/1460] Processing: Babar_Khan_son_of_Tawalat_Shah_Versus_Ghulam_son_o_Babar_Khan_Versus_Ghulam___others.txt
#    ✅ Cleaned: 301 tokens
#
# [122/1460] Processing: Badar_Munir_and_other_versus_The_State_Cr.Misc._20No.15-2009.txt
#    ✅ Cleaned: 436 tokens
#
# [123/1460] Processing: Bahadur_Shah_Versus_Contractor_Rehman_Shah_Bahadur_Shah_versus_Contractor_Rehman_Shah.txt
#    ✅ Cleaned: 206 tokens
#
# [124/1460] Processing: Bakhtawar_Shah_so_Turab_Versus_Khuda_Aman_so_Khu_judgment_20of_20bakhtawar_20shah_20versus_20khuda_20aman_20_27-04-2017_.txt
#    ✅ Cleaned: 392 tokens
#
# [125/1460] Processing: Barat_Ali_Versus_Mst_Maher_Banu_Barat_20Ali.txt
#    ✅ Cleaned: 130 tokens
#
# [144/1460] Processing: CMisc_No_1242015_in_CPLA_No_082015_Rehmat_20Alam_20versus_20Hafiz_20ehsan_20Ullah.txt
#    ✅ Cleaned: 487 tokens
#
# [145/1460] Processing: CMisc_No_252014_in_CPLA_NO_512014_Shaheen-.txt
#    ✅ Cleaned: 40 tokens
#
# [146/1460] Processing: COMPENSATION_FOR_DAMAGES_CAUSED_BY_THE_OVER_FLOW_A_SMC._10-2010_2016_04_20_12_07_02_356.txt
#    ✅ Cleaned: 617 tokens
#
# [147/1460] Processing: COMPLAINT_AGAINST_CIVIL_SUPPLY_smc_20no._202-2013.txt
#    ✅ Cleaned: 2,637 tokens
#
# [148/1460] Processing: COMPLAINT_OF_CONTRACT_EMPLOYEES_OF_BPS-17_18_FRO_Complaint_20of_20contract_20empoyees_20review_20.txt
#    ✅ Cleaned: 167 tokens
#
# [149/1460] Processing: COMPLAINT_OF_CONTRACT_EMPLOYEES_OF_BPS-17_18_FRO_Contract_20employees_20of_20various_20departments_20of_20GB.txt
#    ✅ Cleaned: 139 tokens
#
# [150/1460] Processing: COMPLAINT_SUBMITTED_BY_GENERAL_MANAGER_SARENA_HOTL_Complaint_submitted_by_general_manager.txt
#    ✅ Cleaned: 206 tokens
#
# [151/1460] Processing: COMPLAINT_SUBMITTED_BY_MST_HOORI_COMPLAINT_SUBMITTED_BY_MST._HOORI.txt
#    ✅ Cleaned: 382 tokens
#
# [152/1460] Processing: CONTEMPT_PETITION_NO_02013_IN_SMC_NO_012011_shabbir_hussain_vs_Sajad_Salem_hotiyana___others.txt
#    ✅ Cleaned: 179 tokens
#
# [153/1460] Processing: CPLANo132010_zaheer_20Khan_20vs_20provincial_20Govt.txt
#    ✅ Cleaned: 116 tokens
#
# [154/1460] Processing: CPLANo292009_Muhammad_vs_abdur_Rehaman.txt
#    ✅ Cleaned: 94 tokens
#
# [155/1460] Processing: CPLANo_192009_sadar_Azam.txt
#    ✅ Cleaned: 688 tokens
#
# [156/1460] Processing: CPLA_NO032010_islamic_investment_bank.txt
#    ✅ Cleaned: 710 tokens
#
# [157/1460] Processing: CPLA_NO042013_Mst._20Mumtaz_20Begaum_20versus_20Taj_20Begum.txt
#    ✅ Cleaned: 577 tokens
#
# [158/1460] Processing: CPLA_NO122010_Hasan_sadpara_vs_Govt.txt
#    ✅ Cleaned: 60 tokens
#
# [159/1460] Processing: CPLA_NO152012_Gulab_20Khan_20versus_20Saeed_20khan.txt
#    ✅ Cleaned: 333 tokens
#
# [160/1460] Processing: CPLA_NO182010_All_20Residents_20of_20Mausa_20Shella.txt
#    ✅ Cleaned: 398 tokens
#
# [161/1460] Processing: CPLA_NO192012__3_.Mst._20Zaibun_20Nisa_20vs_20Safi_20ullah_20baig.txt
#    ✅ Cleaned: 388 tokens
#
# [162/1460] Processing: CPLA_NO192014_Chairman_20PARC_20versus_20KHalid_20Ikhlaq.txt
#    ✅ Cleaned: 343 tokens
#
# [163/1460] Processing: CPLA_NO202010_Tahira_20Begum.txt
#    ✅ Cleaned: 374 tokens
#
# [164/1460] Processing: CPLA_NO222009_Muhammad_Ali_vs_commanding_ofvicer.txt
#    ✅ Cleaned: 839 tokens
#
# [165/1460] Processing: CPLA_NO232010_safar_20khan.txt
#    ✅ Cleaned: 124 tokens
#
# [166/1460] Processing: CPLA_NO242012_Vice_20Chancellor_20KIU_20vr_20Mst._20Kaneez_20Fatima.txt
#    ✅ Cleaned: 459 tokens
#
# [167/1460] Processing: CPLA_NO292013_Hussain_20Akber.txt
#    ✅ Cleaned: 247 tokens
#
# [168/1460] Processing: CPLA_NO302009_Hamayoon_Khan.txt
#    ✅ Cleaned: 108 tokens
#
# [169/1460] Processing: CPLA_NO332009_Hassan_Shah_vs_Shahzada_Khan.txt
#    ✅ Cleaned: 107 tokens
#
# [170/1460] Processing: CPLA_NO362009_Meherban_Ali_vs_shakoor_Khan.txt
#    ✅ Cleaned: 727 tokens
#
# [171/1460] Processing: CPLA_NO412014_Suleman_20Versus_20Maroof.txt
#    ✅ Cleaned: 382 tokens
#
# [172/1460] Processing: CPLA_NO442014_Fatime_20Bi_20versus_20Abdur_20Rahim.txt
#    ✅ Cleaned: 419 tokens
#
# [173/1460] Processing: CPLA_NO522014_hussain_20versus_20Syed_20Muhammad_20Ali_20shah.txt
#    ✅ Cleaned: 864 tokens
#
# [174/1460] Processing: CPLA_NO592014_Chairman_20AKESP_20versus_20Mst._20Shabnam.txt
#    ✅ Cleaned: 365 tokens
#
# [175/1460] Processing: CPLA_NO742014_provincial_20Govt_20vs_20Tahira_20Begum.txt
#    ✅ Cleaned: 120 tokens
#
# [176/1460] Processing: CPLA_NO852014_Iftikhar_20Ali_20Versus_20VC_20KIU.txt
#    ✅ Cleaned: 1,240 tokens
#
# [177/1460] Processing: CPLA_NO_042009_abdul_Ghafoor_vs_Ghulam_Muhammad.txt
#    ✅ Cleaned: 919 tokens
#
# [178/1460] Processing: CPLA_NO_062010_Mehboob_Alam_Lone_vs_Chief_Judge_Chief_Court.txt
#    ✅ Cleaned: 69 tokens
#
# [179/1460] Processing: CPLA_NO_072010_CPLA_07-2010_Jumma_Syed_V_Provincial_government.txt
#    ✅ Cleaned: 164 tokens
#
# [180/1460] Processing: CPLA_NO_082013_kamal_20hussain.txt
#    ✅ Cleaned: 338 tokens
#
# [181/1460] Processing: CPLA_NO_092010_jan_Muhammad_vs_Muhammad_Musa.txt
#    ✅ Cleaned: 660 tokens
#
# [182/1460] Processing: CPLA_NO_102010_CPLA_10-2010_muhammad_amn_balghari_vs_provincial_govt_etc.txt
#    ✅ Cleaned: 86 tokens
#
# [183/1460] Processing: CPLA_NO_12011_Collector_20Skardu_20Versus_20Muhammad_20Akber.txt
#    ✅ Cleaned: 676 tokens
#
# [184/1460] Processing: CPLA_NO_132009_Ghulam_Qadir.txt
#    ✅ Cleaned: 576 tokens
#
# [185/1460] Processing: CPLA_NO_152010_haji_Ghulam_Mehdi_vs_provincial_Govt.txt
#    ✅ Cleaned: 331 tokens
#
#    ✅ Cleaned: 204 tokens
#
# [207/1460] Processing: CPLA_No282019_Provincial_Govt_Versus_Attaullah_23._20final_20judgment_20of_20attaullah2.txt
#    ✅ Cleaned: 631 tokens
#
# [208/1460] Processing: CPLA_No312014_Ms_20Ishaq_20Versus_20NBP.txt
#    ✅ Cleaned: 426 tokens
#
# [209/1460] Processing: CPLA_No322009_yawar_Hussain_vs_ansar_Ali.txt
#    ✅ Cleaned: 451 tokens
#
# [210/1460] Processing: CPLA_No362018_Provincial_Govt_and_others_Versus_22._20judgment_20of_20akhtar_20ali_20_conveyance_20allowance_.txt
#    ✅ Cleaned: 1,137 tokens
#
# [211/1460] Processing: CPLA_No382018_Residents_of_Makhor_Vs_Residents_46._20judgment_20of_20residents_20of_20mauza_20makhore.txt
#    ✅ Cleaned: 1,021 tokens
#
# [212/1460] Processing: CPLA_No442020_NHA_through_Chairman_Versus_Affec_19._20NHA_20through_20Chairman_20Vs._20Affectees_20of_20JSR.txt
#    ✅ Cleaned: 1,638 tokens
#
# [213/1460] Processing: CPLA_No502011_Pronvincial_20Government_20Vs_20Faqir_20Shah.txt
#    ✅ Cleaned: 515 tokens
#
# [214/1460] Processing: CPLA_No502019_Govt_of_Gilgit-Baltistan_through_8._20judgment_20of_20dr._20fida.txt
#    ✅ Cleaned: 1,051 tokens
#
# [215/1460] Processing: CPLA_No512018_Govt_of_GB_through_Chief_Secretar_4._20final_20judgment_20of_20shah_20faisal__20luqman_20wali.txt
#    ✅ Cleaned: 1,288 tokens
#
# [216/1460] Processing: CPLA_No542016_Ali_20Afsar_20__20others_20versus_20Ali_20Rehmant_20__20others.txt
#    ✅ Cleaned: 411 tokens
#
# [217/1460] Processing: CPLA_No602014_pROVINCIAL_20gOVERNMENT_20VS_20fIAZ_20aHMED.txt
#    ✅ Cleaned: 398 tokens
#
# [218/1460] Processing: CPLA_No602018_Provincial_Government_through_Chie_15._20judgment_20of_20Raja_20Muhammad_20Haleem_20Khan.txt
#    ✅ Cleaned: 1,393 tokens
#
# [219/1460] Processing: CPLA_No752019_Prov_Govt_of_GB_Vs_Saadat_Khan_1._20judgment_20of_20Saadat_20Khan.txt
#    ✅ Cleaned: 2,495 tokens
#
# [220/1460] Processing: CPLA_No882014_Mst._20Roqia_20Begum_20versus_20Safdar_20Ali.txt
#    ✅ Cleaned: 1,037 tokens
#
# [221/1460] Processing: CPLA_No882015_Mst._20Kaniz_20Batool_20versus_20Prov._20Govt.txt
#    ✅ Cleaned: 89 tokens
#
# [222/1460] Processing: CPLA_No912020_Provincial_Govt_and_others_Vs_Sha_32._20judgment_20of_20sharafat.txt
#    ✅ Cleaned: 1,078 tokens
#
# [223/1460] Processing: CPLA_No942014_Barat_20Ali.txt
#    ✅ Cleaned: 265 tokens
#
# [224/1460] Processing: CPLA_No972018_Govt_of_Gilgit-Baltistan_through_10._20judgment_20of_20Dr._20Qazi_20Muhammad_20Saleem.txt
#    ✅ Cleaned: 849 tokens
#
# [225/1460] Processing: CPLA_No982014_Mst_20Nani.txt
#    ✅ Cleaned: 125 tokens
#
# [308/1460] Processing: CPLA_No_622011_Shukoor_Niaz_vs_Abdul_Aziz_alias.txt
#    ✅ Cleaned: 356 tokens
#
# [309/1460] Processing: CPLA_No_662016_Ajab_Khan_versus_Faizullah___another.txt
#    ✅ Cleaned: 182 tokens
#
# [310/1460] Processing: CPLA_No_672015_Mst._20Haseena.txt
#    ✅ Cleaned: 765 tokens
#
# [311/1460] Processing: CPLA_No_682017_Prov._20Govt_20versus_20All_20Staffmembers_20of_20NAC_20leave_20refused.txt
#    ✅ Cleaned: 154 tokens
#
# [312/1460] Processing: CPLA_No_692014_Ahlian-e-Zail_versus_Prov._Govt.___others.txt
#    ✅ Cleaned: 526 tokens
#
# [313/1460] Processing: CPLA_No_722017_Prov._20Govt_20versus_20Muhammad_20Ghazi.txt
#    ✅ Cleaned: 96 tokens
#
# [314/1460] Processing: CPLA_No_742015_Juma_Khan_versus_NiamatUllah___others.txt
#    ✅ Cleaned: 38 tokens
#
# [315/1460] Processing: CPLA_No_742017_Prov._20Govt_20versus_20Mehdi_20Flour_20Mill.txt
#    ✅ Cleaned: 366 tokens
#
# [316/1460] Processing: CPLA_No_792017_Secretary_20Education_20__20others_20vs_20Sikandar_20Khan.txt
#    ✅ Cleaned: 389 tokens
#
# [317/1460] Processing: CPLA_No_802016_Wajid_Hussain_versus_Prov._Govt.___others.txt
#    ✅ Cleaned: 162 tokens
#
# [318/1460] Processing: CPLA_No_822015_CPLA_no._82-2015.txt
#    ✅ Cleaned: 169 tokens
#
# [319/1460] Processing: CPLA_No_832014_Ghazi_20Johar.txt
#    ✅ Cleaned: 279 tokens
#
# [320/1460] Processing: CPLA_No_862016_VC_20KIU_20vs_20Abdul_20Rasheed-_20leave_20rufused.txt
#    ✅ Cleaned: 95 tokens
#
# [321/1460] Processing: CPLA_No_892020_Govt_of_Gilgit-Baltistan_through_6._20judgment_20of_20safiullah.txt
#    ✅ Cleaned: 613 tokens
#
# [322/1460] Processing: CPLA_No_922015_Rifaqat_Ali_versus_Provincial_Govt..txt
#    ✅ Cleaned: 425 tokens
#
# [323/1460] Processing: CPLA_No_922016_Ibrahim_20__20others_20Vs_20Provincial_20Govt._20__20others.txt
#    ✅ Cleaned: 178 tokens
#
# [324/1460] Processing: CPLA_No_932020_Chief_Election_Commissioner_GB_Vs_45._20Judgment_20of_20Chief_20Election_20Commissioner_20Vs._20M._20Qadeer_20__20others.txt
#    ✅ Cleaned: 2,656 tokens
#
# [325/1460] Processing: CPLA_No_942015_Hunza_Macro_Polo_Traders___Exporter_versu_District_Council_Gilgit.txt
#    ✅ Cleaned: 65 tokens
#
# [326/1460] Processing: CPLA_No_942015_Jumla_Zamindaran_Singul___others_versus_Lambardar_Hila_Khan.txt
#    ✅ Cleaned: 50 tokens
#
# [327/1460] Processing: CPLA_No_962016_Ghulam_20nabi_20versus_20Prov._20Govt_20__20others.txt
#    ✅ Cleaned: 283 tokens
#
# [328/1460] Processing: CPLA_No_972017_Shertullah_20versus_20Mst._20Gul_20Zahida.txt
#    ✅ Cleaned: 150 tokens
#
# [329/1460] Processing: CPLA_No_982016_Rana_Inayat_Hussain_versus_Secretary_Gilgit-B_altistan.txt
#    ✅ Cleaned: 69 tokens
#
# [330/1460] Processing: CPLA_No_982020_Provincial_Govt_through_Chief_Se_2._20final_20Judgment_20of_20Akhtar_20Hussain_20_1_.txt
#    ✅ Cleaned: 778 tokens
#
# [331/1460] Processing: CPLA_UNDER_OBJECTION_No402020_Provincial_Govt_a_28._20judgment_20of_20Manzoor_20Ahmed.txt
#    ✅ Cleaned: 524 tokens
#
# [332/1460] Processing: CPLA_UNDER_OBJECTION_No52019_Provincial_Govt_an_24._20Judgement_20of_20Ishtiaq_20Ahmed.txt
#    ✅ Cleaned: 1,040 tokens
#
# [333/1460] Processing: CPLA_UO_No1522019_Govt_of_GB_through_Chief_Sec_5._20final_20judgment_20of_20nafeesa_20kiran.txt
#    ✅ Cleaned: 731 tokens
#
# [334/1460] Processing: CPLA_Under_Objection_No1422019_Inspector_General_14._20judgment_20of_20Waqar_20Hussain.txt
#    ✅ Cleaned: 574 tokens
#
# [335/1460] Processing: CPLA_Under_Objection_No1452019_Provincial_Govt_17._20judgment_20of_20mehboob_20hussain.txt
#    ✅ Cleaned: 948 tokens
#
# [336/1460] Processing: CPLA_Under_Objection_No172020_Darwesh_and_anothe_9._20judgment_20of_20Darwesh-2.txt
#    ✅ Cleaned: 569 tokens
#
# [337/1460] Processing: CPLA_Under_Objection_No_1132019_Provincial_Govt_25._20Judgment_20of_20Muhammad_20Mashroof_20Khan.txt
#    ✅ Cleaned: 1,390 tokens
#
# [338/1460] Processing: CPLA_Under_Objection_No_132019_Syed_Hamid_Hussai_26._20judgment_20of_20Syed_20Hamid_20Hussain.txt
#    ✅ Cleaned: 1,320 tokens
#
# [339/1460] Processing: CPLA_Under_Objection_No_2482018_Provincial_Govt_21._20final_20judgment_20of_20Zawara_20Baig.txt
#    ✅ Cleaned: 739 tokens
#
# [340/1460] Processing: CPLA_Under_Objection_No_422019_Provincial_Govt_31._20judgment_20of_20Muhamad_20Qayyum.txt
#    ✅ Cleaned: 1,469 tokens
#
# [341/1460] Processing: CPLA_Under_Objection_No_452019_Muhammad_Yaqoob_S_16._20Judgment_20of_20Muhammad_20Yaqoob_201.txt
#    ✅ Cleaned: 1,586 tokens
#
# [342/1460] Processing: CPLA_Under_Objection_No_852019_Govt_of_Gilgit-B_11._20judgement_20of_20Akhtar_20Hussain_20Changazi.txt
#    ✅ Cleaned: 1,394 tokens
#
# [343/1460] Processing: CR_PLA_NO_062010_sher_20Ali_20vs_20The_20state.txt
#    ✅ Cleaned: 1,184 tokens
#
# [344/1460] Processing: C_APPEAL_NO_022015_IN_CPLA_NO_932014_C.Appeal_No._02-2015_in_CPLA_No._93-2014.txt
#    ✅ Cleaned: 149 tokens
#
# [345/1460] Processing: C_APPEAL_NO_162015_CPLA_NO892014_Raja_Shahduran_ALi_vs_habib_ur_rehman.txt
#    ✅ Cleaned: 388 tokens
#
# [346/1460] Processing: C_Appeal_No142015_in_CPLA_No_502014_Amir_20Shah.txt
#    ✅ Cleaned: 133 tokens
#
# [347/1460] Processing: C_Appeal_No352015_Deng_20xio_20bin_20vs_20registrar_20JS.txt
#    ✅ Cleaned: 2,609 tokens
#
# [348/1460] Processing: C_Appeal_No_092014_in_CPLA_No_782014_Muhammad_20Ismail_20verssus_20VC_20KIU.txt
#    ✅ Cleaned: 852 tokens
#
# [349/1460] Processing: C_Appeal_No_122015_In_CPLA_No_392014_Mst._Meherjani_versus_Prov._Govt___others.txt
#    ✅ Cleaned: 393 tokens
#
# [350/1460] Processing: C_Appeal_No_17201_In_CPLA_No_132015_Provincial_Govt._versus_Tauqeer___others.txt
#    ✅ Cleaned: 1,295 tokens
#
# [351/1460] Processing: C_Appeal_No_182015_Ministery_of_Defense_VR_Major_M.Farooq.txt
#    ✅ Cleaned: 735 tokens
#
# [352/1460] Processing: C_Appeal_No_192015_In_CPLA_No_402014_Babar_Khan_Versus_Ghulam___others.txt
#    ✅ Cleaned: 301 tokens
#
# [353/1460] Processing: C_Appeal_No_192016_in_CPLA_No_1052015_Mst._Shabnam_versus_Provincial_Govt.___others_20_1_.txt
#    ✅ Cleaned: 573 tokens
#
# [354/1460] Processing: C_Appeal_No_282016_In_CPLA_No_372013_SHer_Afraz_versus_Prov._Govt.___others.txt
#    ✅ Cleaned: 451 tokens
#
# [355/1460] Processing: C_Appeal_No_292015_In_CPLA_No_932015_Afzal_Khan_versus_Muhammad_Sharif___others.txt
#    ✅ Cleaned: 532 tokens
#
# [356/1460] Processing: C_Appeal_No_382016_in_CPLA_No_422014_Muhammad_Younus_versus_Prov._Govt.___others.txt
#    ✅ Cleaned: 441 tokens
#
# [357/1460] Processing: C_Appeal_No_422016_in_CPLA_No_112016_Ibrar_20Ali_20__20others_20versus_20Provincial_20Governt_20__20others.txt
#    ✅ Cleaned: 446 tokens
#
# [358/1460] Processing: C_Appeal_No_442015_in_CPLA_No_312015_Wajahat_ullah_versus_Provincial_Govt.txt
#    ✅ Cleaned: 414 tokens
#
# [359/1460] Processing: C_Appeal_No_552016_In_CPLA_No_372016_Provincial_Govt.___others_versus_Syeda_Khishwar_Batool.txt
#    ✅ Cleaned: 365 tokens
#
# [360/1460] Processing: C_Appeal_No_832016_in_CPLA_No_1152016_judgment_20of_20nadir_20ali_20khan_20versus_20inam_20ur_20rehman_20_13-04-2017_.txt
#    ✅ Cleaned: 804 tokens
#
# [361/1460] Processing: C_Appeal_No_872016_in_CPLA_No_1002016_NBP_20versus_20Silk_20Rout_20Dry_20Port_20Trust.txt
#    ✅ Cleaned: 836 tokens
#
# [362/1460] Processing: C_MISC_NO_222014_IN_CPLA_NO172013_Ghulam_Haider_Vs_Muhammad___others.txt
#    ✅ Cleaned: 36 tokens
#
# [363/1460] Processing: C_MiscNo_692015_in_CPLA_No_122015_Shahbaz_Khan_VS_Provincail_Govt.___Other.txt
#    ✅ Cleaned: 37 tokens
#
# [364/1460] Processing: C_Misc_NO102016_IN_CPLA_NO832015_sajid_ullah.txt
#    ✅ Cleaned: 413 tokens
#
# [365/1460] Processing: C_Misc_No072013_in_SMC_No_172011_Death_20of_20Child_20due_20to_20collapse_20of_20School_20Boundary_20Wall.txt
#    ✅ Cleaned: 75 tokens
#
# [366/1460] Processing: C_Misc_No_022016_in_SMC_No_092016_Complaint_against_the_custom_authority_at_sost_dry_port.txt
#    ✅ Cleaned: 246 tokens
#
# [367/1460] Processing: C_Misc_No_042013_in_CPLA_NO_62013_Gulbar_Khan_versus_Chief_Election_Commissioner.txt
#    ✅ Cleaned: 120 tokens
#
# [368/1460] Processing: C_Misc_No_1002015_in_CPLA_No_162012_Chairman_PARC_versus_Ejabat_Shah.txt
#    ✅ Cleaned: 504 tokens
#
# [369/1460] Processing: C_Misc_No_1022015_in_CPLA_No_862014_Secretary_20Works_20GB.txt
#    ✅ Cleaned: 1,003 tokens
#
# [370/1460] Processing: C_Misc_No_1022015_in_CPLA_No_862014_Secretary_20Works_20GB_1.txt
#    ✅ Cleaned: 1,003 tokens
#
# [371/1460] Processing: C_Misc_No_1022016_In_CPLA_No_1082016_Prvo._Govt.___others_versus_Ex-Inspecter_M._Hassan.txt
#    ✅ Cleaned: 120 tokens
#
# [372/1460] Processing: C_Misc_No_1072015_in_CPLA_No_372015_C.Misc._No._107-2015_in_cpla_no._37-2015_20_1_.txt
#    ✅ Cleaned: 168 tokens
#
# [373/1460] Processing: C_Misc_No_1092015_In_SMC_No_042013_Muhammad_Shuab_versus_Prov._Govt___others.txt
#    ✅ Cleaned: 43 tokens
#
# [374/1460] Processing: C_Misc_No_1302015_C_Appeal_No_092015_in_CP_Prov._Govt.___others_versus_1619_employees_of_Faminly_planning.txt
#    ✅ Cleaned: 87 tokens
#
# [375/1460] Processing: C_Misc_No_152013_in_CPLA_No_132013_Muhammad_Raheem_Shah_versus_Mastan_Shah.txt
#    ✅ Cleaned: 107 tokens
#
# [376/1460] Processing: C_Misc_No_202015_C_Appeal_No_342015_in_CPLA_Mansha_Ali_Khan_versus_Prov._Govt._Others.txt
#    ✅ Cleaned: 455 tokens
#
# [377/1460] Processing: C_Misc_No_212014_CPLA_No_052013_Muhammad_Abuzar_vr_Chairman_PARC.txt
#    ✅ Cleaned: 389 tokens
#
# [378/1460] Processing: C_Misc_No_222015_in_CPLA_No_232014_Provincial_Government_versus__Raja_Muzaffar_Hussain_DIG.txt
#    ✅ Cleaned: 196 tokens
#
# [379/1460] Processing: C_Misc_No_222016_in_CPLA_No_262016_Mehboob_Riaz_versus_Fiyaz_Ahmed___others.txt
#    ✅ Cleaned: 538 tokens
#
# [380/1460] Processing: C_Misc_No_232013_C_Appeal_No_022011_in_CPL_Muhammad_Amin_versus_Govt._of_Gb.txt
#    ✅ Cleaned: 580 tokens
#
# [381/1460] Processing: C_Misc_No_282016_Yawar_Abbas_versus_SEcretary_Kashmir_Affairs.txt
#    ✅ Cleaned: 179 tokens
#
# [382/1460] Processing: C_Misc_No_312016_in_CPLA_No_362016_Ubaid-ur-Rehman_versus_Govt._of_Gb.txt
#    ✅ Cleaned: 391 tokens
#
# [383/1460] Processing: C_Misc_No_322016_C_Misc_No_012013_in_CPLA_Shah_Raees_Khan_versus_Prov._Govt._others.txt
#    ✅ Cleaned: 168 tokens
#
# [384/1460] Processing: C_Misc_No_332014_IN_CPLA_NO_572014_judgment_of_rehman_manzor_versus_amir_shehzad.txt
#    ✅ Cleaned: 760 tokens
#
# [385/1460] Processing: C_Misc_No_352015_in_CPLA_No_262015_Provincial_Govt._through_CS_versus_Dr._Ghulam_Ali.txt
#    ✅ Cleaned: 406 tokens
#
# [386/1460] Processing: C_Misc_No_352016_in_CPLA_No_142016_Khush_Baig_versus_Provincial_Govt.___others.txt
#    ✅ Cleaned: 146 tokens
#
# [387/1460] Processing: C_Misc_No_362016_C_Misc_No_302016_in_CPLA_N_Mr._Imran_Raza_Versus_Govt._GB.txt
#    ✅ Cleaned: 61 tokens
#
# [388/1460] Processing: C_Misc_No_382016_in_CPLA_No_158_2016_Secretary_20KA_NA_20versus_20Niamat_20Khan_20through_20legal_20heirs.txt
#    ✅ Cleaned: 156 tokens
#
# [389/1460] Processing: C_Misc_No_472013_In_CPLA_No_382013_Qalandar___others_versus_Munawar.txt
#    ✅ Cleaned: 57 tokens
#
# [390/1460] Processing: C_Misc_No_502014_in_Cr_PLA_No_622014_Shaban_Ali_etc_versus_Mst._Zainaba_etec.txt
#    ✅ Cleaned: 354 tokens
#
# [391/1460] Processing: C_Misc_No_532016_CPLA_No_492014_The_Agriculture_department___others_vs_Haij_Juma_Shah.txt
#    ✅ Cleaned: 247 tokens
#
# [392/1460] Processing: C_Misc_No_542016_In_CPLA_No_592016_Muhammad_Ali_Akhter___others_versus_Prov.Govt___others.txt
#    ✅ Cleaned: 95 tokens
#
# [393/1460] Processing: C_Misc_No_552016_in_CPLA_No_602016_Prov._Govt.___others_versus_Khalid_Mehmood___others.txt
#    ✅ Cleaned: 114 tokens
#
# [394/1460] Processing: C_Misc_No_582014_In_SMC_No_042013_Shahab-ud-Din_versus_Prov._Govt___others.txt
#    ✅ Cleaned: 90 tokens
#
# [395/1460] Processing: C_Misc_No_672016_In_CPLA_No_642015_Prov._Govt___others_versus_Fazila_Shaheen.txt
#    ✅ Cleaned: 76 tokens
#
# [396/1460] Processing: C_Misc_No_692014_C_Misc_No_1262015C_App_Den_Xiao_Bin_Versus_Registrar_Joint_Stock.txt
#    ✅ Cleaned: 179 tokens
#
# [397/1460] Processing: C_Misc_No_722016_In_CPLA_No_622016_Yuosaf_ALi___another_versus_Mst._Asia_Brohi.txt
#    ✅ Cleaned: 52 tokens
#
# ...
#    ✅ Cleaned: 1,136 tokens
#
# [1361/1460] Processing: The_State_Versus_Ashfaq_Hussain_another_The_20State_20versus_20Ashfaq_20Hussain_20__20another_20Bail_20matter.txt
#    ✅ Cleaned: 357 tokens
#
# [1362/1460] Processing: The_State_Versus_Asif_Abbass_so_Musa_and_others_CrPLA_No._02-2014_State_v._Asif_Abbas.txt
#    ✅ Cleaned: 301 tokens
#
# [1363/1460] Processing: The_State_Versus_Aziz-ur-Rehman_the_20State_20versus_20Aziz-ur-Rehman_20bail_20granted.txt
#    ✅ Cleaned: 430 tokens
#
# [1364/1460] Processing: The_State_Versus_Bilal_Ahmed_03_others_the_State_versus_Bilal_Ahmed___others.txt
#    ✅ Cleaned: 392 tokens
#
# [1365/1460] Processing: The_State_Versus_Doulat_Mir_another_The_20State_20vs_20Doulat_20Mir_20__20Another.txt
#    ✅ Cleaned: 440 tokens
#
# [1366/1460] Processing: The_State_Versus_Ehsan_Ali_Advocate_06_others_The_State_versus_Ehsan_Ali_Advocate___others.txt
#    ✅ Cleaned: 248 tokens
#
# [1367/1460] Processing: The_State_Versus_Iftikhar_Hussain_The_State_Versu_baba_20jan_20__20others.txt
#    ✅ Cleaned: 13,424 tokens
#
# [1368/1460] Processing: The_State_Versus_Khan_Bibi_Alias_Khani_the_20state_20vs_20Khan_20Bibi.txt
#    ✅ Cleaned: 123 tokens
#
# [1369/1460] Processing: The_State_Versus_Mashroof_Cr._MISC_No._06-2010_The_State_Vs_Mashroof.txt
#    ✅ Cleaned: 125 tokens
#
# [1370/1460] Processing: The_State_Versus_Muhammad_Afzal_Mulhammad_afzal_vs_the_state.txt
#    ✅ Cleaned: 510 tokens
#
# [1371/1460] Processing: The_State_Versus_Muhammad_Afzal_The_20State_20Versus_20Muhammad_20Afzal.txt
#    ✅ Cleaned: 5,445 tokens
#
# [1372/1460] Processing: The_State_Versus_Muhammad_Azam_02_others_Muhammad_Azam_Vs_The_State.txt
#    ✅ Cleaned: 6,979 tokens
#
# [1373/1460] Processing: The_State_Versus_Nadeem_Abbas_02_others_The_20State_20versus_20Nadeem_20Abbas_20__20others.txt
#    ✅ Cleaned: 2,426 tokens
#
# [1374/1460] Processing: The_State_Versus_Naveed_Akhtar_Alias_Jani_The_20State_20versus_20Naveed_20Akhtar_20Alias_20Jani.txt
#    ✅ Cleaned: 854 tokens
#
# [1375/1460] Processing: The_State_Versus_Niamat_Wali_The_State_versus_Niamat_Wali.txt
#    ✅ Cleaned: 821 tokens
#
# [1376/1460] Processing: The_State_Versus_Nusrat_Ali_Khan_others_The_20State_20Versus_20Nusrat_20Ali_20Khand_20__20others_20_time_20barred_.txt
#    ✅ Cleaned: 82 tokens
#
# [1377/1460] Processing: The_State_Versus_Qari_Asif_others_the_20State_20versus_20Qari_20Asif_20__20others.txt
#    ✅ Cleaned: 428 tokens
#
# [1378/1460] Processing: The_State_Versus_Qari_Muzammil_others_the_20State_20versus_20Qari_20Muzamil.txt
#    ✅ Cleaned: 201 tokens
#
# [1379/1460] Processing: The_State_Versus_Sadaqat_Jan_state_20vs_20sadaqat_20jan.txt
#    ✅ Cleaned: 1,476 tokens
#
# [1380/1460] Processing: The_State_Versus_Saleem_Khan_07_others_The_20State_20versus_20Saleem_20Khan_20__20others.txt
#    ✅ Cleaned: 170 tokens
#
# [1381/1460] Processing: The_State_Versus_Shabrang_others_The_20State_20versus_20Shabrang_20__20others.txt
#    ✅ Cleaned: 513 tokens
#
# [1382/1460] Processing: The_State_Versus_Shah_Hussain_SO_Shah_Muhammad_Shah_Hussain.txt
#    ✅ Cleaned: 510 tokens
#
# [1383/1460] Processing: The_State_Versus_Shakeel_Ahmed_02_others_The_20State_20versus_20Shakeel_20Ahmed_20__20others.txt
#    ✅ Cleaned: 439 tokens
#
# [1384/1460] Processing: The_State_Versus_Shamsu_Rehman_The_20State_20Versus_20Shamsu_20Rehman.txt
#    ✅ Cleaned: 359 tokens
#
# [1385/1460] Processing: The_State_Versus_Sharafat_Hussain_King_So_Asghar_Under_Objection_No._10-2013_State_v._Sharafat_Hussain.txt
#    ✅ Cleaned: 440 tokens
#
# [1386/1460] Processing: The_State_Versus_Sher_Gayas_The_20State_20versus_20Sher_20Ghayas.txt
#    ✅ Cleaned: 648 tokens
#
# [1387/1460] Processing: The_State_Versus_Sufi_Ali_so_Abdul_Karim_and_othe__10_._Sufi_Ali_.txt
#    ✅ Cleaned: 1,803 tokens
#
# [1388/1460] Processing: The_State_others_Versus_Ehsanullah_03_others_The_20State_20__20others_20versus_20Ehsanullah_20__20others.txt
#    ✅ Cleaned: 771 tokens
#
# [1389/1460] Processing: The_State_through_ANF_Versus_Ishaq_Ahmed_The_20State_20through_20NAF_20versus_20Ishaq_20AHmed.txt
#    ✅ Cleaned: 901 tokens
#
# [1390/1460] Processing: The_State_through_Chief_Secretary_Gilgit-Baltistan_Cr._PLA_No._01-2014.txt
#    ✅ Cleaned: 121 tokens
#
# [1391/1460] Processing: The_State_through_Deputy_Advocate_General_GB_Versu_The_20State_20versus_20Ghafoor_20__20others.txt
#    ✅ Cleaned: 254 tokens
#
# [1392/1460] Processing: The_State_through_Federal_Investigation_Agency_FI_The_20state_20through_20FIA_20Vs_20Abdur_20Rahim.txt
#    ✅ Cleaned: 100 tokens
#
# [1393/1460] Processing: The_State_through_National_Accountability_Bureau_V_The_20State_20through_20NAB_20VS_20Pervaiz_20Iqbal.txt
#    ✅ Cleaned: 750 tokens
#
# [1394/1460] Processing: The_State_through_National_Accountability_Bureau_V_The_State_through_NAB_versus_Qalab_ALi.txt
#    ✅ Cleaned: 2,136 tokens
#
# [1395/1460] Processing: The_State_through_Police_Station_City_Astore_Versu_The_20State_20versus_20Shafiq_20son_20of_20daulat_20khan.txt
#    ✅ Cleaned: 196 tokens
#
# [1396/1460] Processing: The_State_through_Police_Station_City_Gilgit_Versu_The_20State_20Versus_20Imran_20Ali_20son_20of_20Muhammad_20Hanif.txt
#    ✅ Cleaned: 106 tokens
#
# [1397/1460] Processing: The_State_through_Police_Station_City_Gilgit_Versu_The_20State_20versus_20Muhammad_20Nadeem.txt
#    ✅ Cleaned: 649 tokens
#
# [1398/1460] Processing: The_State_through_Police_Station_Gahkuch_Versus_Me_The_20State_20through_20police_20Station_20District_20Ghizer_20versus_20Mehboob_20Alam.txt
#    ✅ Cleaned: 225 tokens
#
# [1399/1460] Processing: The_State_through_Police_Station_Nomal_Gilgit_Vers_the_20State_20versus_20Ali_20Ahmed_20Jan.txt
#    ✅ Cleaned: 849 tokens
#
# [1400/1460] Processing: The_State_versus_Haider_The_20State_20versus_20Haider.txt
#    ✅ Cleaned: 698 tokens
#
# [1401/1460] Processing: The_State_versus_Sulieman_The_20State_20versus_20Sulieman_20_2_.txt
#    ✅ Cleaned: 1,350 tokens
#
# [1402/1460] Processing: The_state_Versus_Huzarat_Hussain_The_state_Vs_Hazarat_Hussain.txt
#    ✅ Cleaned: 398 tokens
#
# [1403/1460] Processing: The_state_Versus_Najamâud_âDin_and_another_the_state_najam-_ud-din_and_another.txt
#    ✅ Cleaned: 234 tokens
#
# [1404/1460] Processing: The_water_and_Power_Development_Authority_WAPDA_smc_20no._2012-2011.txt
#    ✅ Cleaned: 220 tokens
#
# [1405/1460] Processing: The_water_and_power_Development_Authority_WAPDA__8_._20the_20wapda_20sad_20para_20vs_20ahliyan_20sad_20para.txt
#    ✅ Cleaned: 213 tokens
#
# [1406/1460] Processing: Tota_Jan_Versus_The_State_Tota_Jan_15-3-2010.txt
#    ✅ Cleaned: 935 tokens
#
# [1407/1460] Processing: UNDER_OBJECTION_No_132015_Deputy_20Commissioner_20versus_20Akbar_20Shah.txt
#    ✅ Cleaned: 62 tokens
#
# [1408/1460] Processing: Ubaid-ur-Rehman_Muqaddam_Versus_Govt_of_Gilgit-Ba_Ubaid-ur-Rehman_versus_Govt._of_Gb.txt
#    ✅ Cleaned: 391 tokens
#
# [1409/1460] Processing: Umar_Khan_Son_of_Khuda_Yar_112_others_Versus_All_Umar_Khan_versus_All_Jumla_Malikan_Zangari_Heti.txt
#    ✅ Cleaned: 784 tokens
#
# [1410/1460] Processing: Under_Objection_No012015_Muhammad_20Iqball_20versus_20Government_20of_20GB.txt
#    ✅ Cleaned: 47 tokens
#
# [1411/1460] Processing: Under_Objection_No1532017_The_20State_20Versus_20Nusrat_20Ali_20Khand_20__20others_20_time_20barred_.txt
#    ✅ Cleaned: 82 tokens
#
# [1412/1460] Processing: Under_Objection_No1552017_The_20State_20versus_20Shafiq_20son_20of_20daulat_20khan.txt
#    ✅ Cleaned: 196 tokens
#
# [1413/1460] Processing: Under_Objection_No1562017_Provincial_20Government_20__20others_20versus_20Hazar_20Ali_20__20others_20_TB_.txt
#    ✅ Cleaned: 86 tokens
#
# [1414/1460] Processing: Under_Objection_No612015_Shafqat_20Ali_20versus_20Prov._20Govt_20__20others.txt
#    ✅ Cleaned: 86 tokens
#
# [1415/1460] Processing: Under_Objection_No_1022016_Khalid_Akber_versus_Chairman_Board_of_Governor_Cadet_College_sks.txt
#    ✅ Cleaned: 103 tokens
#
# [1416/1460] Processing: Under_Objection_No_1072017_in_Cr_Appeal_No_15_Qalar_20Muhammad_20versus_20Riaz_20__20others.txt
#    ✅ Cleaned: 110 tokens
#
# [1417/1460] Processing: Under_Objection_No_1432016_NAB_20versus_20Muhammad_20Ali_20Yugvi.txt
#    ✅ Cleaned: 262 tokens
#
# [1418/1460] Processing: Under_Objection_No_1592019_Provincial_Govt_Vs_A_33._20Judgment_20Prov_20Gov_20v_20Abir_20Khan.txt
#    ✅ Cleaned: 985 tokens
#
# [1419/1460] Processing: Under_Objection_No_1732018_Manzoor_20Ahmed_20advocate_20versus_20Malik_20Kifayat-ur-Rehman.txt
#    ✅ Cleaned: 97 tokens
#
# [1420/1460] Processing: Under_Objection_No_1862017_in_CrPLA_NO_402017_Tahir_20Iqbal_20__20others_20versus_20Abdul_20Ghaffar_20and_20another.txt
#    ✅ Cleaned: 224 tokens
#
# [1421/1460] Processing: Under_Objection_No_262018_Muhammad_20Ibrahim_20vs_20the_20state.txt
#    ✅ Cleaned: 35 tokens
#
# [1422/1460] Processing: Under_Objection_No_302018_in_Civil_Appeal_No_27_saeed_20gul_20vs_20secretary_20KA_GB.txt
#    ✅ Cleaned: 68 tokens
#
# [1423/1460] Processing: Under_Objection_No_322016_Federal_Board_versus_Dildar_Hussain___others.txt
#    ✅ Cleaned: 164 tokens
#
# [1424/1460] Processing: Under_Objection_No_722017_Civil_20Aviation_20authority_20versus_20Irshad_20Ali.txt
#    ✅ Cleaned: 222 tokens
#
# [1425/1460] Processing: Under_Objection_No_762014_Tati_Khan_versus_Munir_Manager_ZTBL.txt
#    ✅ Cleaned: 31 tokens
#
# [1426/1460] Processing: Under_Objection_No_812017_Sher_20Wali_20__20others_20versus_20Prov._20Govt_20__20others.txt
#    ✅ Cleaned: 185 tokens
#
# [1427/1460] Processing: Under_objection_No_102013_Under_Objection_No._10-2013_State_v._Sharafat_Hussain.txt
#    ✅ Cleaned: 440 tokens
#
# [1428/1460] Processing: Up-Gradation_of_Judicial_Officers_up-Gradation_of_Judicial_Officers.txt
#    ✅ Cleaned: 13,335 tokens
#
# [1429/1460] Processing: Up-gradation_of_Judicial_OfficersStaff_and_Allowa_up-gradation_20of_20Judicial_20Officer-allowances.txt
#    ✅ Cleaned: 571 tokens
#
# [1430/1460] Processing: User_Manual_For_LHC_Attendance_System_User_Manual_LHC_Mobile_Attendance_System.txt
#    ✅ Cleaned: 218 tokens
#
# [1431/1460] Processing: User_Manual_For_LHC_Attendance_System_User_Manual_LHC_Mobile_Attendance_System_1.txt
#    ✅ Cleaned: 218 tokens
#
# [1432/1460] Processing: Usman_Ali_son_of_Farman_Ali_Versus_VC_KIU_02_oth_Usman_20Ali_20versus_20VC_20KIU.txt
#    ✅ Cleaned: 465 tokens
#
# [1433/1460] Processing: Vice_Chancellor_KIU_02_others_Versus_Abdul_Rashe_VC_20KIU_20vs_20Abdul_20Rasheed-_20leave_20rufused.txt
#    ✅ Cleaned: 95 tokens
#
# [1434/1460] Processing: Vice_Chancellor_KIU_others_Versus_Mst_Nazia_Nas_VC_20KIU_20vs_20Mst._20Nazia_20Naseer.txt
#    ✅ Cleaned: 146 tokens
#
# [1435/1460] Processing: Vice_Chancellor_KIU_versus_Mst_Kaneez_Fatima_Vice_20Chancellor_20KIU_20vr_20Mst._20Kaneez_20Fatima.txt
#    ✅ Cleaned: 459 tokens
#
# [1436/1460] Processing: Vice_Chancellor_Karakorum_International_University_VC_20KIU_20__20other_20versus_20Nisar_20Alam.txt
#    ✅ Cleaned: 568 tokens
#
# [1437/1460] Processing: Wajahat_Ullah_Nasim_Versus_Provincial_Government_G_Wajahat_ullah_versus_Provincial_Govt.txt
#    ✅ Cleaned: 414 tokens
#
# [1438/1460] Processing: Wajid_Ali_so_Ghulam_Nabi_and_09_others_Versus_Mur_judgment_20of_20wajid_20ali_20versus_20murtaza_20dated_20_17-4-2017_.txt
#    ✅ Cleaned: 401 tokens
#
# [1439/1460] Processing: Wajid_Hussain_Versus_Provincial_Govt_Others_Wajid_Hussain_versus_Prov._Govt.___others.txt
#    ✅ Cleaned: 162 tokens
#
# [1440/1460] Processing: Walayat_Ali_Versus_Shabbier_Hussain_others_Walayat_20Ali_20versus_20Shabbir_20Hussaiin_20__20others_20leave_20refused.txt
#    ✅ Cleaned: 164 tokens
#
# [1441/1460] Processing: Waris_others_Versus_Ali_Muhammad_others_waris_20__20others_20Versus_20Ali_20Muhammad.txt
#    ✅ Cleaned: 85 tokens
#
# [1442/1460] Processing: Wazir_Ali_others_Versus_Residents_of_Mohallah_Bo_Wazir_Ali_Pari_versus_Residentce_of_Bottichow_skd.txt
#    ✅ Cleaned: 380 tokens
#
# [1443/1460] Processing: Wazir_Versus_The_State_Wazir___another_versus_The_State.txt
#    ✅ Cleaned: 1,177 tokens
#
# [1444/1460] Processing: Yad_Gari_others_Versus_Government_of_Gilgit-Balt_Yad_20Gari_20__20others_20versus_20Govt._20of_20GB.txt
#    ✅ Cleaned: 321 tokens
#
# [1445/1460] Processing: Yawar_Hussain_So_Haji_Fida_Hussain_Versus_Anwar_A_yawar_Hussain_vs_ansar_Ali.txt
#    ✅ Cleaned: 451 tokens
#
# [1446/1460] Processing: Yousuf_Ali_another_Versus_Mst_Asia_Brohi_Yuosaf_ALi___another_versus_Mst._Asia_Brohi.txt
#    ✅ Cleaned: 52 tokens
#
# [1447/1460] Processing: Zafar_Iqbal_MD_NATCO_Gilgit-Baltistan_Versus_Muha_Zafar_20Iqbal_20vs_20Muhammad_20Naseem.txt
#    ✅ Cleaned: 260 tokens
#
# [1448/1460] Processing: Zafar_Iqbal_Versus_Baba_Jan_and_2_others_Zafar_Iqbal_Versus_Baba_Jab_EC.txt
#    ✅ Cleaned: 744 tokens
#
# [1449/1460] Processing: Zaheer_Khan_Versus_Provincial_Government_through_zaheer_20Khan_20vs_20provincial_20Govt.txt
#    ✅ Cleaned: 116 tokens
#
# [1450/1460] Processing: Zahir_Abbas_So_Azur_Khan_Versus_The_State_zahir_abbas_vs_the_state.txt
#    ✅ Cleaned: 1,325 tokens
#
# [1451/1460] Processing: Zakir_Hussain_son_of_Muhammad_Afzal_Versus_The_Sta_Zakir_20Hussain_20Versus_20the_20STate.txt
#    ✅ Cleaned: 110 tokens
#
# [1452/1460] Processing: Zamindaran-e-Samigal_Bala_and_pain_Versus_Zamindar_Zamindaran-e-Samigal_vs_Zamindara-e-Dodoshal.txt
#    ✅ Cleaned: 615 tokens
#
# [1453/1460] Processing: Zarai_Taraqiati_Bank_Versus_Sher_Ali_Baig_others_Zaria_20Taraqiati_20Bank_20versus_20Sher_20Ali_20Baig.txt
#    ✅ Cleaned: 1,085 tokens
#
# [1454/1460] Processing: Zarmast_Khan_so_Jehangir_Versus_Samair_Kahan_cr.misc_no._16-2010.txt
#    ✅ Cleaned: 353 tokens
#
# [1455/1460] Processing: Zeebo_other_versus_The_State_Zeebo_20versus_20The_20State.txt
#    ✅ Cleaned: 212 tokens
#
# [1456/1460] Processing: Zia-ur-Rehman_and_4_others_Versus_Sadar_Azam_and_1_sadar_Azam.txt
#    ✅ Cleaned: 688 tokens
#
# [1457/1460] Processing: Zubair_Ahmed_Versus_The_State_Zubair_Ahmed_Versus_the_Satate.txt
#    ✅ Cleaned: 839 tokens
#
# [1458/1460] Processing: amsheed_Khan_etc_versus_Provincial_Government_etc_CPLA_01-2010_Jamshed_Khan_v_Provincial_gov_etc.txt
#    ✅ Cleaned: 294 tokens
#
# [1459/1460] Processing: gbv.txt
#    ✅ Cleaned: 3,490 tokens
#
# [1460/1460] Processing: slamic_Investment_Co-operative_Society_Aliabad_Hun_islamic_investment_bank.txt
#    ✅ Cleaned: 710 tokens
#
# 💾 Saving processed data...
#    ✅ Vocabulary: 25,833 words saved
#    ✅ All processed data saved
#
# 📊 Generating statistics report...
#    ✅ Statistics reports generated
#
# 🎨 Creating visualizations...
#    ✅ Visualizations created
#
# ================================================================================
# 📊 PREPROCESSING SUMMARY
# ================================================================================
#
# 📁 CORPUS LOCATION:
#    C:\Users\Armaghan Rafique\Desktop\AI Project\cleaned_corpus
#
# 📊 BASIC STATISTICS:
#    Documents Processed: 1,460
#    Total Sentences: 85,682
#    Total Words (Raw): 2,181,951
#    Total Words (Cleaned): 1,048,901
#    Vocabulary Size: 25,833
#    Processing Time: 33.14 seconds
#
# 📈 AVERAGE PER DOCUMENT:
#    Words: 718
#    Sentences: 59
#
# 🔤 TOP 10 MOST FREQUENT WORDS:
#     1. learned                16,512 (1.57%)
#     2. gilgit                 14,239 (1.36%)
#     3. chief                  10,945 (1.04%)
#     4. ..                      9,137 (0.87%)
#     5. page                    8,746 (0.83%)
#     6. order                   8,381 (0.80%)
#     7. -baltistan              8,258 (0.79%)
#     8. appeal                  7,337 (0.70%)
#     9. muhammad                5,984 (0.57%)
#    10. law                     5,848 (0.56%)
#
# 📂 CREATED FOLDERS:
#    • cleaned_docs/ - Individual cleaned documents
#    • tokens/ - Tokenized versions
#    • statistics/ - Statistical reports
#    • visualizations/ - Charts and graphs
#
# 📄 CREATED FILES:
#    • complete_corpus.txt - All documents combined
#    • vocabulary.txt - Complete vocabulary list
#    • word_frequencies.json - Word frequency data
#    • document_tokens.json - Document-token mapping
#    • corpus_statistics.json - Complete statistics
#
# ================================================================================
# 🎉 CORPUS PREPROCESSING COMPLETED!
# ================================================================================
#
# 📂 Your corpus is ready at:
#    C:\Users\Armaghan Rafique\Desktop\AI Project\cleaned_corpus
#
# 📝 Next steps you can take:
#    1. Train word embeddings (Word2Vec, GloVe)
#    2. Create TF-IDF matrix
#    3. Train topic models (LDA, NMF)
#    4. Build a search engine
#    5. Train a text classifier
